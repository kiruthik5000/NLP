# %%
import pandas as pd
import matplotlib.pyplot as plt

# %%
df = pd.read_csv("./data/c2.csv", parse_dates=['DATE'])
df['DATE'].astype("datetime64[us]")
df.set_index('DATE', inplace=True)

# %%
df.info()
# Out:
# <class 'pandas.DataFrame'>
# DatetimeIndex: 397 entries, 1988-01-01 to 2021-01-01
# Data columns (total 2 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   Consumption               397 non-null    float64
#  1   Festivals/Special_events  397 non-null    int64
# dtypes: float64(1), int64(1)
# memory usage: 9.3 KB

# %%
plt.figure(figsize=(10, 6))
plt.plot(df["Consumption"])
plt.title("Power Consumption Over Time")
plt.xlabel("Date")
plt.ylabel("Power Consumption")
plt.legend(["Electiricity Consumption"])
plt.show()
