# %%
import pandas as pd
import matplotlib.pyplot as plt
from statsmodels.tsa.seasonal import seasonal_decompose

# %%
df = pd.read_csv("./Data/c3.csv", parse_dates=['DATE'])
df.set_index('DATE', inplace=True)
df
# Out:
#             Consumption  Festivals/Special_events
# DATE
# 1988-01-01     107.5052                         6
# 1988-02-01     105.6720                         1
# 1988-03-01      97.4502                         1
# 1988-04-01      92.4714                         1
# 1988-05-01      90.3151                         1
# ...                 ...                       ...
# 2020-09-01     133.6154                         8
# 2020-10-01     128.6137                         6
# 2020-11-01     132.3359                         5
# 2020-12-01     149.7212                         7
# 2021-01-01     164.4048                         7
#
# [397 rows x 2 columns]

# %%
decomposition = seasonal_decompose(
    df['Consumption'],
    model='additive',
    period=12
)

# %%
plt.figure(figsize=(10, 6))

plt.subplot(4, 1, 1)
plt.plot(decomposition.observed)
plt.title("Original Electricity Consumption")

plt.subplot(412)
plt.plot(decomposition.trend)
plt.title("Trend Component")

plt.subplot(413)
plt.plot(decomposition.seasonal)
plt.title("Seasonal Component")

plt.subplot(414)
plt.plot(decomposition.resid)
plt.title("Residual Component")

plt.tight_layout()
plt.show()

# %%
import pandas as pd
ML471_S1_Datafile_Concept = pd.read_csv('C:\Users\Kiruthik\Downloads\4d0ce9bd-9d9b-41f2-bfe6-8754cfaec85ade1Ub (2)\ML471_S1_Datafile_Concept.csv', sep = ',')
ML471_S1_Datafile_Concept
# Out:
#   Cell In[15], line 2
#     ML471_S1_Datafile_Concept = pd.read_csv('C:\Users\Kiruthik\Downloads\4d0ce9bd-9d9b-41f2-bfe6-8754cfaec85ade1Ub (2)\ML471_S1_Datafile_Concept.csv', sep = ',')
#                                             ^
# SyntaxError: (unicode error) 'unicodeescape' codec can't decode bytes in position 2-3: truncated \UXXXXXXXX escape
