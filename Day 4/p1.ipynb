# %%
import pandas as pd
import matplotlib.pyplot as plt
from statsmodels.tsa.statespace.sarimax import SARIMAX

# %%
df = pd.read_csv("./data/p1.csv", parse_dates=['Date'])
df.sort_values('Date', inplace=True)
df.set_index('Date', inplace=True)

y = df['Close']

# %%
model = SARIMAX(
    y,
    order=(0, 0, 0),
    seasonal_order=(0, 1, [0], 12)
)

result = model.fit()
forecast = result.fittedvalues[100:]
# Out:
# D:\ML_College\NLP\.venv\Lib\site-packages\statsmodels\tsa\base\tsa_model.py:473: ValueWarning: No frequency information was provided, so inferred frequency ME will be used.
#   self._init_dates(dates, freq)
# D:\ML_College\NLP\.venv\Lib\site-packages\statsmodels\tsa\base\tsa_model.py:473: ValueWarning: No frequency information was provided, so inferred frequency ME will be used.
#   self._init_dates(dates, freq)

# %%
plt.figure(figsize=(10, 6))
plt.plot(y[100:], label='Actual')
plt.plot(forecast, color='orange', label='Seasonal Naive')
plt.legend()
plt.title("Seasonal Naive Model")
plt.show()
